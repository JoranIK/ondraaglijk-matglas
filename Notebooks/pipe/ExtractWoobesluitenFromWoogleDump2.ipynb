# %%
# Imports
import os
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %run T:/Desktop/UvA/Jaar3/OndragelijkRepo/noclone/WoogleDumps/LoadWoogleDump.ipynb
# %run ../WoogleDumps/LoadWoogleDump.ipynb
# Out:
# C:\Users\Joran\AppData\Local\Temp\ipykernel_3408\1749375695.py:3: DtypeWarning: Columns (9,10,11,12,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   document_dataframe = pd.read_csv(DUMP_PATH+ 'woo_documents.csv.gz').set_index('dc_identifier')
# (1220289, 39)
# (1395128, 54)
# all data is in the dataframe cdf

# %%
# make multi_idex
cdf['foi_documentId']= cdf.index
cdf.set_index(['foi_documentId','foi_pageNumber' ], inplace=True)

# %%
print(cdf.columns, cdf.shape)
cdf.head()
# Out:
# Index(['foi_dossierType', 'foi_bodyText', 'foi_bodyTextOCR', 'foi_hasOCR',
#        'foi_redacted', 'foi_nrRedactedRegions', 'foi_contourArea',
#        'foi_textArea', 'foi_charArea', 'foi_percentageTextAreaRedacted',
#        'foi_percentageCharAreaRedacted', 'foi_imageArea',
#        'foi_imageCoversFullPage', 'foi_bodyTextJaccard', 'foi_dossierId',
#        'dc_title', 'dc_description', 'foi_fileName', 'dc_format', 'dc_source',
#        'dc_type', 'foi_nrPages', 'foi_pdfDateCreated', 'foi_pdfDateModified',
#        'foi_pdfCreator', 'foi_pdfProducer', 'foi_pdfAuthor', 'foi_pdfCompany',
#        'foi_pdfTitle', 'foi_pdfSubject', 'foi_pdfKeywords', 'foi_fairiscore',
#        'dc_title_dossier', 'dc_description_dossier', 'dc_type_dossier',
#        'dc_type_description', 'dc_publisher', 'dc_publisher_name',
#        'dc_source_dossier', 'foi_publishedDate', 'dc_date_year',
#        'foi_requestDate', 'foi_decisionDate', 'foi_valuation',
# ...

# %%
Woobesluiten = cdf[((cdf.dc_type_dossier=='2i')& (cdf.dc_type=='besluit'))]
Woobesluiten.shape
# Out:
# (180339, 53)

# %%
Woobesluiten.foi_dossierId.unique().size, Woobesluiten.dc_source.unique().size
# Out:
# (8358, 8167)

# %%
Woobesluiten.to_csv('woobesluiten1212.csv.gz')

# !ls -lh
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
